# %% [markdown]
# # Total Revenue

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch revenue data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data (focus on revenues)
income_statement = abnb.financials
revenue_data = income_statement.loc['Total Revenue'].transpose()

# Display the revenue data
print("AirBnb's Revenue Data (in billions):")
print(revenue_data)

# Check for NaN values in revenue data
if revenue_data.isnull().any():
    print("\nWarning: NaN values detected in revenue data. Handling them...")
    revenue_data = revenue_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # revenue_data = revenue_data.fillna(revenue_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
revenue_data.index = pd.to_datetime(revenue_data.index)
revenue_data = revenue_data.sort_index()

# Create a numerical index for regression
X = np.array(range(len(revenue_data))).reshape(-1, 1)  # Independent variable (time)
y = revenue_data.values  # Dependent variable (revenue)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future revenues (for the next 3 years)
future_X = np.array(range(len(revenue_data), len(revenue_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_revenue = model.predict(future_X)

# Combine historical and predicted revenues
future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_revenue_series = pd.Series(predicted_revenue, index=future_dates)

# Plot historical and predicted revenues
plt.figure(figsize=(10, 5))
plt.plot(revenue_data.index, revenue_data.values, label='Historical Revenue', marker='o')
plt.plot(predicted_revenue_series.index, predicted_revenue_series.values, label='Predicted Revenue', marker='o', linestyle='--')
plt.title("AirBnb's Revenue Prediction")
plt.xlabel("Year")
plt.ylabel("Revenue (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted revenues
print("\nPredicted Revenues for the Next 3 Years:")
for year, revenue in zip(predicted_revenue_series.index.year, predicted_revenue_series.values):
    print(f"{year}: ${revenue:.2f} billion")
# Out:
# AirBnb's Revenue Data (in billions):
# 2024-12-31    11102000000.0
# 2023-12-31     9917000000.0
# 2022-12-31     8399000000.0
# 2021-12-31     5992000000.0
# 2020-12-31              NaN
# Name: Total Revenue, dtype: object
#
# ...
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12604\1396184875.py:44: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Revenues for the Next 3 Years:
# 2025: $13064500000.00 billion
# 2026: $14749300000.00 billion
# 2027: $16434100000.00 billion

# %%
# Let's See what other items in the Income Statement.

import yfinance as yf
import pandas as pd

# Fetch income statement data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data
income_statement = abnb.financials

# Display the income statement to check the available labels
print("Income Statement Data:")
print(income_statement)

# Check the correct label for COGS
# Out:
# Income Statement Data:
#                                                        2024-12-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.205
# Normalized EBITDA                                    2618000000.0
# Total Unusual Items                                           0.0
# Total Unusual Items Excluding Goodwill                        0.0
# Net Income From Continuing Operation Net Minori...   2648000000.0
# Reconciled Depreciation                                65000000.0
# Reconciled Cost Of Revenue                           1878000000.0
# EBITDA                                               2618000000.0
# EBIT                                                 2553000000.0
# Net Interest Income                                   818000000.0
# Interest Expense                                              NaN
# Interest Income                                       818000000.0
# ...

# %% [markdown]
# # COGS

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch COGS data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data (focus on COGS)
income_statement = abnb.financials
cogs_data = income_statement.loc['Cost Of Revenue'].transpose()

# Display the COGS data
print("AirBnb's COGS Data (in billions):")
print(cogs_data)

# Check for NaN values in revenue data
if cogs_data.isnull().any():
    print("\nWarning: NaN values detected in cogs data. Handling them...")
    cogs_data = cogs_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # revenue_data = revenue_data.fillna(revenue_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
cogs_data.index = pd.to_datetime(cogs_data.index)
cogs_data = cogs_data.sort_index()

# Create a numerical index for regression
X = np.array(range(len(cogs_data))).reshape(-1, 1)  # Independent variable (time)
y = cogs_data.values  # Dependent variable (COGS)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future COGS (for the next 3 years)
future_X = np.array(range(len(cogs_data), len(cogs_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_cogs = model.predict(future_X)

# Combine historical and predicted COGS
future_dates = pd.date_range(start=cogs_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_cogs_series = pd.Series(predicted_cogs, index=future_dates)

# Plot historical and predicted COGS
plt.figure(figsize=(10, 5))
plt.plot(cogs_data.index, cogs_data.values, label='Historical COGS', marker='o')
plt.plot(predicted_cogs_series.index, predicted_cogs_series.values, label='Predicted COGS', marker='o', linestyle='--')
plt.title("AirBnb's COGS Prediction")
plt.xlabel("Year")
plt.ylabel("COGS (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted COGS
print("\nPredicted COGS for the Next 3 Years:")
for year, cogs in zip(predicted_cogs_series.index.year, predicted_cogs_series.values):
    print(f"{year}: ${cogs:.2f} billion")
# Out:
# AirBnb's COGS Data (in billions):
# 2024-12-31    1878000000.0
# 2023-12-31    1703000000.0
# 2022-12-31    1499000000.0
# 2021-12-31    1156000000.0
# 2020-12-31             NaN
# Name: Cost Of Revenue, dtype: object
#
# ...
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12604\143284906.py:44: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=cogs_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted COGS for the Next 3 Years:
# 2025: $2151500000.00 billion
# 2026: $2388500000.00 billion
# 2027: $2625500000.00 billion

# %% [markdown]
# # Gross Profit

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch COGS data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data (focus on COGS)
income_statement = abnb.financials
GP_data = income_statement.loc['Gross Profit'].transpose()

# Display the COGS data
print("AirBnb's COGS Data (in billions):")
print(GP_data)

# Check for NaN values in revenue data
if GP_data.isnull().any():
    print("\nWarning: NaN values detected in cogs data. Handling them...")
    GP_data = GP_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # revenue_data = revenue_data.fillna(revenue_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
GP_data.index = pd.to_datetime(GP_data.index)
GP_data = GP_data.sort_index()

# Create a numerical index for regression
X_GP = np.array(range(len(GP_data))).reshape(-1, 1)  # Independent variable (time)
y_GP = GP_data.values  # Dependent variable (COGS)

# Fit a linear regression model
model1 = LinearRegression()
model1.fit(X_GP, y_GP)

# Predict future COGS (for the next 3 years)
future_X_GP = np.array(range(len(GP_data), len(GP_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_GP = model1.predict(future_X_GP)

# Combine historical and predicted COGS
future_dates_GP = pd.date_range(start=GP_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_GP_series = pd.Series(predicted_GP, index=future_dates_GP)

# Plot historical and predicted COGS
plt.figure(figsize=(10, 5))
plt.plot(GP_data.index, GP_data.values, label='Historical GP', marker='o')
plt.plot(predicted_GP_series.index, predicted_GP_series.values, label='Predicted GP', marker='o', linestyle='--')
plt.title("AirBnb's Gross Profit Prediction")
plt.xlabel("Year")
plt.ylabel("GP (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted COGS
print("\nPredicted Gross Profit for the Next 3 Years:")
for year, GP in zip(predicted_GP_series.index.year, predicted_GP_series.values):
    print(f"{year}: ${GP:.2f} billion")
# Out:
# AirBnb's COGS Data (in billions):
# 2024-12-31    9224000000.0
# 2023-12-31    8214000000.0
# 2022-12-31    6900000000.0
# 2021-12-31    4836000000.0
# 2020-12-31             NaN
# Name: Gross Profit, dtype: object
#
# ...
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13836\101682474.py:44: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates_GP = pd.date_range(start=GP_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Gross Profit for the Next 3 Years:
# 2025: $10913000000.00 billion
# 2026: $12360800000.00 billion
# 2027: $13808600000.00 billion

# %% [markdown]
# # Total Expense

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch  data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data 
income_statement = abnb.financials
TE_data = income_statement.loc['Total Expenses'].transpose()

# Display the data
print("AirBnb's Total Expense Data (in billions):")
print(TE_data)

# Check for NaN values in revenue data
if TE_data.isnull().any():
    print("\nWarning: NaN values detected in cogs data. Handling them...")
    TE_data = TE_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # revenue_data = revenue_data.fillna(revenue_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
TE_data.index = pd.to_datetime(TE_data.index)
TE_data = TE_data.sort_index()

# Create a numerical index for regression
X_TE = np.array(range(len(TE_data))).reshape(-1, 1)  # Independent variable (time)
y_TE = TE_data.values  # Dependent variable (COGS)

# Fit a linear regression model
model2 = LinearRegression()
model2.fit(X_TE, y_TE)

# Predict future COGS (for the next 3 years)
future_X_TE = np.array(range(len(TE_data), len(TE_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_TE = model2.predict(future_X_TE)

# Combine historical and predicted
future_dates_TE = pd.date_range(start=TE_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_TE_series = pd.Series(predicted_TE, index=future_dates_TE)

# Plot historical and predicted
plt.figure(figsize=(10, 5))
plt.plot(TE_data.index, TE_data.values, label='Historical TE', marker='o')
plt.plot(predicted_TE_series.index, predicted_TE_series.values, label='Predicted TE', marker='o', linestyle='--')
plt.title("AirBnb's Total Expense Prediction")
plt.xlabel("Year")
plt.ylabel("TE (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted COGS
print("\nPredicted Total Expense for the Next 3 Years:")
for year, TE in zip(predicted_TE_series.index.year, predicted_TE_series.values):
    print(f"{year}: ${TE:.2f} billion")
# Out:
# AirBnb's Total Expense Data (in billions):
# 2024-12-31    8549000000.0
# 2023-12-31    8399000000.0
# 2022-12-31    6508000000.0
# 2021-12-31    5450000000.0
# 2020-12-31             NaN
# Name: Total Expenses, dtype: object
#
# ...
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13836\3408777824.py:44: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates_TE = pd.date_range(start=TE_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Total Expense for the Next 3 Years:
# 2025: $10023500000.00 billion
# 2026: $11142300000.00 billion
# 2027: $12261100000.00 billion

# %% [markdown]
# # Predict future revenues based on hypothetical future COGS

# %%
#Use COGS to predict revenues
# Retrieve COGS and revenue data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch financial data
symbol = 'ABNB'
abnb = yf.Ticker(symbol)

# Get income statement data (focus on COGS and Revenues)
income_statement = abnb.financials
cogs_data = income_statement.loc['Cost Of Revenue'].transpose()
revenue_data = income_statement.loc['Total Revenue'].transpose()

# Display the COGS and revenue data
print("AirBnb's COGS Data (in billions):")
print(cogs_data)
print("\AirBnb's Revenue Data (in billions):")
print(revenue_data)

# Prepare data for regression
cogs_data.index = pd.to_datetime(cogs_data.index)
revenue_data.index = pd.to_datetime(revenue_data.index)

# Check for NaN values and handle them (drop NaN values)
if cogs_data.isnull().any() or revenue_data.isnull().any():
    print("\nWarning: NaN values detected in COGS or Revenue. Handling them...")
    # Drop rows where either COGS or Revenue is NaN
    valid_rows = ~cogs_data.isnull() & ~revenue_data.isnull()
    cogs_data = cogs_data[valid_rows]
    revenue_data = revenue_data[valid_rows]

# Sort the data by date
cogs_data = cogs_data.sort_index()
revenue_data = revenue_data.sort_index()

# Create a numerical index for regression
X = cogs_data.values.reshape(-1, 1)  # Independent variable (COGS)
y = revenue_data.values  # Dependent variable (Revenue)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future revenues based on hypothetical future COGS
future_cogs = np.array(range(int(cogs_data.values[-1]), int(cogs_data.values[-1]) + 3)).reshape(-1, 1)
predicted_revenue = model.predict(future_cogs)

# Combine historical and predicted revenues
future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_revenue_series = pd.Series(predicted_revenue, index=future_dates)

# Plot historical COGS vs. Revenue
plt.figure(figsize=(10, 5))
plt.scatter(cogs_data, revenue_data, label='Historical Data', color='blue')
plt.plot(cogs_data, model.predict(X), label='Regression Line', color='orange', linestyle='--')
plt.scatter(future_cogs, predicted_revenue, label='Predicted Revenue', color='red', marker='o')
plt.title("AirBnb's Revenue Prediction Based on COGS")
plt.xlabel("COGS (in billions)")
plt.ylabel("Revenue (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted revenues
print("\nPredicted Revenues for the Next 3 Years Based on COGS:")
for year, revenue in zip(predicted_revenue_series.index.year, predicted_revenue_series.values):
    print(f"{year}: ${revenue:.2f} billion")
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\A'
# <>:21: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12604\693399700.py:21: SyntaxWarning: invalid escape sequence '\A'
#   print("\AirBnb's Revenue Data (in billions):")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12604\693399700.py:53: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# AirBnb's COGS Data (in billions):
# 2024-12-31    1878000000.0
# 2023-12-31    1703000000.0
# 2022-12-31    1499000000.0
# 2021-12-31    1156000000.0
# 2020-12-31             NaN
# Name: Cost Of Revenue, dtype: object
# \AirBnb's Revenue Data (in billions):
# 2024-12-31    11102000000.0
# 2023-12-31     9917000000.0
# 2022-12-31     8399000000.0
# 2021-12-31     5992000000.0
# 2020-12-31              NaN
# Name: Total Revenue, dtype: object
#
# ...

# %%
net_income = df_combined['Net_Income'].dropna()
X = np.arange(len(net_income)).reshape(-1, 1)
y = net_income.values

model = LinearRegression()
model.fit(X, y)

future_net_income = model.predict(np.arange(len(net_income), len(net_income) + 3).reshape(-1, 1))
future_dates = pd.date_range(start=net_income.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
future_net_income_series = pd.Series(future_net_income, index=future_dates)

plt.plot(net_income, label='Historical Net Income')
plt.plot(future_net_income_series, label='Predicted Net Income', linestyle='--')
plt.title("Net Income Forecast")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13836\978146152.py:9: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=net_income.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')

# %%
operating_income = df_combined['Operating_Income'].dropna()
X = np.arange(len(operating_income)).reshape(-1, 1)
y = operating_income.values

model = LinearRegression()
model.fit(X, y)

future_op_income = model.predict(np.arange(len(operating_income), len(operating_income) + 3).reshape(-1, 1))
future_dates = pd.date_range(start=operating_income.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
future_op_income_series = pd.Series(future_op_income, index=future_dates)

plt.plot(operating_income, label='Historical Operating Income')
plt.plot(future_op_income_series, label='Predicted Operating Income', linestyle='--')
plt.title("Operating Income Forecast")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13836\1187076004.py:9: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=operating_income.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
